# %%
"""
We define the usage of capitals in a word to be right when one of the following cases holds:

All letters in this word are capitals, like "USA".
All letters in this word are not capitals, like "leetcode".
Only the first letter in this word is capital, like "Google".
Given a string word, return true if the usage of capitals in it is right.

 

Example 1:

Input: word = "USA"
Output: true
Example 2:

Input: word = "FlaG"
Output: false


"""

# %%
def detectCapitalUse(word):
    first_char = word[0]
    upper_char = first_char.upper()
    if not word:
        return False

    if word.upper() == word or word.lower() == word or (word.lower().replace(first_char, upper_char) == word):
        return True
    return False

# %%
word = 'Amazon'
lower_char = word[0].lower()
upper_char = word[0].upper()

if not word:
    print(False)

if word.upper() == word or word.lower() == word or (upper_char+word[1:]) == word:
    print(True)
print(False)
# Out:
# True
# False
