# %%
nums = [1,2,3,1]
num_set = set(nums)

# %%
len(num_set)
# Out:
# 3

# %%
len(nums)
# Out:
# 4

# %%
def containsDuplicate(nums):
    """
    :type nums: List[int]
    :rtype: bool
    """
    num_set = set(nums)
    return len(num_set) == len(nums)

# %%
containsDuplicate(nums)
# Out:
# False
