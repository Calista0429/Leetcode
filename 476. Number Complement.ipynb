# %%
num = 5

bin_n = bin(num)[2:]
bin_n = list(bin_n)
for idx, n in enumerate(bin_n):
    if n == '1':
        bin_n[idx] = '0'
    else:
        bin_n[idx] = '1'

# %%
bin_n
# Out:
# ['0', '1', '0']

# %%
bin(num)[2:]
# Out:
# '101'

# %%
string = "1234"

# %%
list(string)[0] =  '4'

# %%
''.join(bin_n)
# Out:
# '010'

# %%
int('0b'+''.join(bin_n), 2)
# Out:
# 2
