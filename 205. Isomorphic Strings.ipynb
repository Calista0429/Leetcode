# %%
def isIsomorphic(s, t):
    ismor_map = {}
    
    #Edge case
    if not s or not t or len(s) != len(t):
        return False


    for sc, tc in zip(s,t):
        if sc in ismor_map:
            if ismor_map[sc] != tc: #Example: s='foo', t='bar'
                return False
            elif tc not in ismor_map.values(): #Example: s='bar', t='foo'
                return False
        char_map[sc] = tc
    return True

# %%
isIsomorphic(s, t)
# Out:
# True

# %%
s = 'foo'
t = 'bar' 
def isIsomorphic(s, t):
    return len(set(s)) == len(set(t)) == len(set(zip(s,t)))

# %%
set(zip(s,t))
# Out:
# {('f', 'b'), ('o', 'a'), ('o', 'r')}

# %%
首先对s字符串和t字符串做取集合操作，这样就剩下不重复的字符。如果按照题意，s中的字符能够被t中的字符替代的话，那么它们的字符组合需要和s和t的字符串集合长度相等。
如果长度不相等，那么一定出现了无法替代的情况。
在这个例子中 s = 'paper', t = 'title' 
s_set = {'p','a','e','r'}
t_set = {'t', 'i', 'l', 'e'}
zip(s_set, t_set) = {('p', 't'), ('a', 'i'), ('e', 'l'), ('r', 'e') }
这时候判断长度是否相等即可

如果出现 s = 'foo'
t = 'bar' 
s_set = {'f', 'o'}
t_set = {'b', 'a', 'r'}
s和t的字符串集合已经不相等，因此返回false
